

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# %%
ids = [matched_ids.replace(".nii", "") for matched_ids in matched_ids]
count=0
# Traverse the input directory structure
for patient_id in os.listdir(input_dir):
    patient_dir = os.path.join(input_dir, patient_id)

    if os.path.isdir(patient_dir):
        for series_id in os.listdir(patient_dir):
            if series_id in ids:
                count+=1
                print("\n\n\nMatched Series ID:   ",series_id)
                series_dir = os.path.join(patient_dir, series_id)
                print("series_dir",series_dir)
                output_subdir = os.path.join(output_dir, patient_id,series_id)
                print("output_subdir",output_subdir)
                os.makedirs(output_subdir, exist_ok=True)
                # Run TotalSegmentator on the matched series directory
                # !TotalSegmentator -i {series_dir} -o {output_subdir} -ot 'nifti' -rs spleen kidney_left kidney_right liver colon small_bowel
                print(f"Processed: {series_id}")
                print("="*100)
print("\n\nNo. of ids processsed total: ",count)
# Zip the output files
zip_path = '/kaggle/working/masks.zip'
with zipfile.ZipFile(zip_path, 'w') as zipf:
    for root, _, files in os.walk(output_dir):
        for file in files:
            file_path = os.path.join(root, file)
            zipf.write(file_path, os.path.relpath(file_path, output_dir))
print(f"Segmentation masks have been zipped to {zip_path}")
# Out:
# Matched Series ID:    33526
# series_dir /kaggle/input/rsna-2023-abdominal-trauma-detection/train_images/54183/33526
# output_subdir /kaggle/working/masks/54183/33526
# /opt/conda/bin/TotalSegmentator:5: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import require
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Converting dicom to nifti...
#   found image with shape (512, 512, 827)
# Resampling...
#   Resampled in 24.89s
# Predicting part 1 of 2 ...
# Predicting part 2 of 2 ...
#   Predicted in 82.12s
# Resampling...
# Saving segmentations...
# 100%|█████████████████████████████████████████████| 6/6 [00:09<00:00,  1.53s/it]
#   Saved in 12.79s
# Processed: 33526
# ...
#
#
#
# Matched Series ID:    22479
# series_dir /kaggle/input/rsna-2023-abdominal-trauma-detection/train_images/37459/22479
# output_subdir /kaggle/working/masks/37459/22479
# ...

# %%
import os
import shutil

# Define the directory to be cleaned
working_dir = '/kaggle/working/'

# Ensure the directory exists
if os.path.exists(working_dir):
    # Iterate over all the files and directories in the specified directory
    for filename in os.listdir(working_dir):
        file_path = os.path.join(working_dir, filename)
        try:
            # Check if it is a file or directory and delete it
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f'Failed to delete {file_path}. Reason: {e}')

print(f"All files and directories in {working_dir} have been deleted.")
# Out:
# All files and directories in /kaggle/working/ have been deleted.
